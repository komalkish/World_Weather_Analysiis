# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
from citipy import citipy
import time
from datetime import datetime
from config import weather_api_key
import numpy as np

# %%
lats = np.random.uniform(low = -90.000, high = 90.000, size = 1500)
langs = np.random.uniform(low = -180.000, high = 180.000, size = 1500)
lat_langs = zip(lats, langs)
lat_langs
coordinates = list(lat_langs)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
clean_cities =[]
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in clean_cities:
        clean_cities.append(city)

# %%
# create an empty list to hold the weather data
city_data = []
# Print the begining of the logging
print("Begining Data Retrieval     ")
print("____________________________")

#create counters
record_count = 1
set_count = 1

for i, city in enumerate(clean_cities):
    #group cities
    if (i % 50 == 0 and i >=50):
        set_count +=1
        record_count +=1
        time.sleep(60)
    #create and endpoint URL
    city_url = url +"&q="+ city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count+=1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lat"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except Exception as e:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Begining Data Retrieval
# ____________________________
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | clinton
# Processing Record 3 of Set 1 | lavrentiya
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | aquiraz
# Processing Record 7 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 1 | upernavik
# Processing Record 9 of Set 1 | codrington
# Processing Record 10 of Set 1 | yar-sale
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | emerald
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | waipawa
# Processing Record 17 of Set 1 | hovd
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | nome
# Processing Record 20 of Set 1 | richards bay
# Processing Record 21 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 1 | fare
# Processing Record 23 of Set 1 | ayan
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | formoso do araguaia
# City not found. Skipping...
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | flinders
# Processing Record 28 of Set 1 | metamorfosis
# City not found. Skipping...
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | erzin
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | katav-ivanovsk
# Processing Record 33 of Set 1 | te anau
# Processing Record 34 of Set 1 | ca mau
# Processing Record 35 of Set 1 | aconibe
# Processing Record 36 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 1 | dunedin
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | torbay
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 1 | ironton
# Processing Record 44 of Set 1 | tual
# Processing Record 45 of Set 1 | khatanga
# Processing Record 46 of Set 1 | port hardy
# Processing Record 47 of Set 1 | sorong
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | jumla
# Processing Record 52 of Set 2 | provideniya
# Processing Record 53 of Set 2 | muswellbrook
# Processing Record 54 of Set 2 | kahului
# Processing Record 55 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 56 of Set 2 | puerto ayora
# Processing Record 57 of Set 2 | saskylakh
# Processing Record 58 of Set 2 | east london
# Processing Record 59 of Set 2 | aklavik
# Processing Record 60 of Set 2 | sawtell
# Processing Record 61 of Set 2 | ribeira grande
# Processing Record 62 of Set 2 | rio gallegos
# Processing Record 63 of Set 2 | bambous virieux
# Processing Record 64 of Set 2 | tautira
# Processing Record 65 of Set 2 | lebu
# Processing Record 66 of Set 2 | grindavik
# Processing Record 67 of Set 2 | bredasdorp
# Processing Record 68 of Set 2 | aksarka
# Processing Record 69 of Set 2 | kodiak
# Processing Record 70 of Set 2 | barrow
# Processing Record 71 of Set 2 | yadgir
# Processing Record 72 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 73 of Set 2 | pevek
# Processing Record 74 of Set 2 | port alfred
# Processing Record 75 of Set 2 | khorinsk
# Processing Record 76 of Set 2 | pangai
# Processing Record 77 of Set 2 | hermanus
# Processing Record 78 of Set 2 | los chiles
# Processing Record 79 of Set 2 | los llanos de aridane
# Processing Record 80 of Set 2 | port blair
# Processing Record 81 of Set 2 | mar del plata
# Processing Record 82 of Set 2 | chokurdakh
# Processing Record 83 of Set 2 | cayenne
# Processing Record 84 of Set 2 | cacoal
# Processing Record 85 of Set 2 | bluff
# Processing Record 86 of Set 2 | yellowknife
# Processing Record 87 of Set 2 | nelson bay
# Processing Record 88 of Set 2 | new norfolk
# Processing Record 89 of Set 2 | himensulan
# Processing Record 90 of Set 2 | lompoc
# Processing Record 91 of Set 2 | vestmannaeyjar
# Processing Record 92 of Set 2 | north bend
# Processing Record 93 of Set 2 | cherskiy
# Processing Record 94 of Set 2 | general pico
# Processing Record 95 of Set 2 | port chester
# Processing Record 96 of Set 2 | ancud
# Processing Record 97 of Set 2 | fairbanks
# Processing Record 98 of Set 2 | humberto de campos
# Processing Record 99 of Set 2 | natal
# Processing Record 100 of Set 2 | bethel
# Processing Record 101 of Set 2 | byumba
# Processing Record 103 of Set 3 | vaini
# Processing Record 104 of Set 3 | thompson
# Processing Record 105 of Set 3 | prince rupert
# Processing Record 106 of Set 3 | waingapu
# Processing Record 107 of Set 3 | albany
# Processing Record 108 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 109 of Set 3 | cape town
# Processing Record 110 of Set 3 | saint-francois
# Processing Record 111 of Set 3 | tuktoyaktuk
# Processing Record 112 of Set 3 | san patricio
# Processing Record 113 of Set 3 | verkhoyansk
# Processing Record 114 of Set 3 | crotone
# Processing Record 115 of Set 3 | dikson
# Processing Record 116 of Set 3 | chengdu
# Processing Record 117 of Set 3 | victoria
# Processing Record 118 of Set 3 | rantepao
# Processing Record 119 of Set 3 | balaipungut
# Processing Record 120 of Set 3 | alofi
# Processing Record 121 of Set 3 | longyearbyen
# Processing Record 122 of Set 3 | saint-philippe
# Processing Record 123 of Set 3 | semey
# Processing Record 124 of Set 3 | umm lajj
# Processing Record 125 of Set 3 | salalah
# Processing Record 126 of Set 3 | sechura
# Processing Record 127 of Set 3 | arkhipo-osipovka
# Processing Record 128 of Set 3 | yunjinghong
# City not found. Skipping...
# Processing Record 129 of Set 3 | inuvik
# Processing Record 130 of Set 3 | clarence town
# Processing Record 131 of Set 3 | beloha
# Processing Record 132 of Set 3 | carnarvon
# Processing Record 133 of Set 3 | pacasmayo
# Processing Record 134 of Set 3 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 135 of Set 3 | middle island
# Processing Record 136 of Set 3 | esperance
# Processing Record 137 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 138 of Set 3 | iaciara
# Processing Record 139 of Set 3 | broome
# Processing Record 140 of Set 3 | marsa matruh
# Processing Record 141 of Set 3 | ashtian
# Processing Record 142 of Set 3 | westport
# Processing Record 143 of Set 3 | sao filipe
# Processing Record 144 of Set 3 | san carlos de bariloche
# Processing Record 145 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 146 of Set 3 | san policarpo
# Processing Record 147 of Set 3 | mahebourg
# Processing Record 148 of Set 3 | nemuro
# Processing Record 149 of Set 3 | skjervoy
# Processing Record 150 of Set 3 | tuatapere
# Processing Record 151 of Set 3 | yichang
# Processing Record 152 of Set 3 | sampit
# Processing Record 154 of Set 4 | greenville
# Processing Record 155 of Set 4 | kapaa
# Processing Record 156 of Set 4 | severo-kurilsk
# Processing Record 157 of Set 4 | vao
# Processing Record 158 of Set 4 | basco
# Processing Record 159 of Set 4 | orizona
# Processing Record 160 of Set 4 | vardo
# Processing Record 161 of Set 4 | chuy
# Processing Record 162 of Set 4 | castro
# Processing Record 163 of Set 4 | tsiroanomandidy
# Processing Record 164 of Set 4 | hofn
# Processing Record 165 of Set 4 | alice springs
# Processing Record 166 of Set 4 | nikolskoye
# Processing Record 167 of Set 4 | souillac
# Processing Record 168 of Set 4 | port elizabeth
# Processing Record 169 of Set 4 | luanda
# Processing Record 170 of Set 4 | ranapur
# Processing Record 171 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 172 of Set 4 | tobermory
# Processing Record 173 of Set 4 | dingle
# Processing Record 174 of Set 4 | valenca
# Processing Record 175 of Set 4 | avarua
# Processing Record 176 of Set 4 | cabo san lucas
# Processing Record 177 of Set 4 | biltine
# Processing Record 178 of Set 4 | almaznyy
# Processing Record 179 of Set 4 | kaitong
# Processing Record 180 of Set 4 | kruisfontein
# Processing Record 181 of Set 4 | buluang
# Processing Record 182 of Set 4 | egvekinot
# Processing Record 183 of Set 4 | mahon
# Processing Record 184 of Set 4 | ucluelet
# Processing Record 185 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 186 of Set 4 | balaguer
# Processing Record 187 of Set 4 | nanortalik
# Processing Record 188 of Set 4 | constitucion
# Processing Record 189 of Set 4 | merauke
# Processing Record 190 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 191 of Set 4 | bentiu
# Processing Record 192 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 193 of Set 4 | gubbi
# Processing Record 194 of Set 4 | yushala
# Processing Record 195 of Set 4 | kattivakkam
# Processing Record 196 of Set 4 | meulaboh
# Processing Record 197 of Set 4 | lasa
# Processing Record 198 of Set 4 | cochabamba
# Processing Record 199 of Set 4 | zhoucheng
# Processing Record 200 of Set 4 | kushima
# Processing Record 201 of Set 4 | mount isa
# Processing Record 202 of Set 4 | college
# Processing Record 203 of Set 4 | kocevje
# Processing Record 205 of Set 5 | salinopolis
# Processing Record 206 of Set 5 | kasese
# Processing Record 207 of Set 5 | itiuba
# Processing Record 208 of Set 5 | ambon
# Processing Record 209 of Set 5 | riyadh
# Processing Record 210 of Set 5 | port lincoln
# Processing Record 211 of Set 5 | sitka
# Processing Record 212 of Set 5 | arlit
# Processing Record 213 of Set 5 | bosaso
# Processing Record 214 of Set 5 | preobrazheniye
# Processing Record 215 of Set 5 | vanimo
# Processing Record 216 of Set 5 | jasper
# Processing Record 217 of Set 5 | saldanha
# Processing Record 218 of Set 5 | chimoio
# Processing Record 219 of Set 5 | saint thomas
# Processing Record 220 of Set 5 | pisco
# Processing Record 221 of Set 5 | general roca
# Processing Record 222 of Set 5 | saint george
# Processing Record 223 of Set 5 | linxia
# Processing Record 224 of Set 5 | baijiantan
# Processing Record 225 of Set 5 | san cristobal
# Processing Record 226 of Set 5 | fortuna
# Processing Record 227 of Set 5 | fukue
# Processing Record 228 of Set 5 | dudinka
# Processing Record 229 of Set 5 | dwarka
# Processing Record 230 of Set 5 | bajo baudo
# City not found. Skipping...
# Processing Record 231 of Set 5 | katobu
# Processing Record 232 of Set 5 | vanino
# Processing Record 233 of Set 5 | airai
# Processing Record 234 of Set 5 | male
# Processing Record 235 of Set 5 | iqaluit
# Processing Record 236 of Set 5 | cidreira
# Processing Record 237 of Set 5 | nishihara
# Processing Record 238 of Set 5 | lodja
# Processing Record 239 of Set 5 | bani
# Processing Record 240 of Set 5 | coquimbo
# Processing Record 241 of Set 5 | beringovskiy
# Processing Record 242 of Set 5 | osa
# Processing Record 243 of Set 5 | batagay-alyta
# Processing Record 244 of Set 5 | alyangula
# Processing Record 245 of Set 5 | itaberai
# Processing Record 246 of Set 5 | kologriv
# Processing Record 247 of Set 5 | pulgaon
# Processing Record 248 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 249 of Set 5 | sao sebastiao
# Processing Record 250 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 251 of Set 5 | mount gambier
# Processing Record 252 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 253 of Set 5 | touros
# Processing Record 254 of Set 5 | tasiilaq
# Processing Record 256 of Set 6 | san matias
# Processing Record 257 of Set 6 | colesville
# Processing Record 258 of Set 6 | erdenet
# Processing Record 259 of Set 6 | moose factory
# Processing Record 260 of Set 6 | gat
# Processing Record 261 of Set 6 | praia
# Processing Record 262 of Set 6 | calawag
# Processing Record 263 of Set 6 | killorglin
# Processing Record 264 of Set 6 | ketchikan
# Processing Record 265 of Set 6 | leningradskiy
# Processing Record 266 of Set 6 | launceston
# Processing Record 267 of Set 6 | sinazongwe
# Processing Record 268 of Set 6 | vitim
# Processing Record 269 of Set 6 | mahibadhoo
# Processing Record 270 of Set 6 | jalu
# Processing Record 271 of Set 6 | faya
# Processing Record 272 of Set 6 | tahta
# Processing Record 273 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 274 of Set 6 | tucumcari
# Processing Record 275 of Set 6 | luoyang
# Processing Record 276 of Set 6 | fort nelson
# Processing Record 277 of Set 6 | sur
# Processing Record 278 of Set 6 | conde
# Processing Record 279 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 280 of Set 6 | pucara
# Processing Record 281 of Set 6 | padang
# Processing Record 282 of Set 6 | puerto escondido
# Processing Record 283 of Set 6 | makat
# Processing Record 284 of Set 6 | sisimiut
# Processing Record 285 of Set 6 | moerai
# Processing Record 286 of Set 6 | ust-kuyga
# Processing Record 287 of Set 6 | kargat
# Processing Record 288 of Set 6 | itoman
# Processing Record 289 of Set 6 | shieli
# Processing Record 290 of Set 6 | velykyy klyuchiv
# Processing Record 291 of Set 6 | stara vyzhivka
# Processing Record 292 of Set 6 | pangody
# Processing Record 293 of Set 6 | berdigestyakh
# Processing Record 294 of Set 6 | wasilla
# Processing Record 295 of Set 6 | mugur-aksy
# Processing Record 296 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 297 of Set 6 | raudeberg
# Processing Record 298 of Set 6 | dong hoi
# Processing Record 299 of Set 6 | stekolnyy
# City not found. Skipping...
# Processing Record 300 of Set 6 | deputatskiy
# Processing Record 301 of Set 6 | tura
# Processing Record 302 of Set 6 | baft
# Processing Record 303 of Set 6 | namibe
# Processing Record 304 of Set 6 | nawa
# Processing Record 305 of Set 6 | urubicha
# Processing Record 307 of Set 7 | tigil
# Processing Record 308 of Set 7 | galveston
# Processing Record 309 of Set 7 | puerto palomas
# Processing Record 310 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 311 of Set 7 | nacogdoches
# Processing Record 312 of Set 7 | umm bab
# Processing Record 313 of Set 7 | puerto del rosario
# Processing Record 314 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 315 of Set 7 | rundu
# Processing Record 316 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 317 of Set 7 | sistranda
# Processing Record 318 of Set 7 | port hedland
# Processing Record 319 of Set 7 | vila velha
# Processing Record 320 of Set 7 | zhireken
# Processing Record 321 of Set 7 | coahuayana
# Processing Record 322 of Set 7 | komsomolskiy
# Processing Record 323 of Set 7 | turka
# Processing Record 324 of Set 7 | makinsk
# Processing Record 325 of Set 7 | saucillo
# Processing Record 326 of Set 7 | polovinnoye
# Processing Record 327 of Set 7 | jacmel
# Processing Record 328 of Set 7 | oistins
# Processing Record 329 of Set 7 | berlevag
# Processing Record 330 of Set 7 | tiksi
# Processing Record 331 of Set 7 | la ronge
# Processing Record 332 of Set 7 | trairi
# Processing Record 333 of Set 7 | leshan
# Processing Record 334 of Set 7 | tilichiki
# Processing Record 335 of Set 7 | viedma
# Processing Record 336 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 337 of Set 7 | ormara
# Processing Record 338 of Set 7 | nouadhibou
# Processing Record 339 of Set 7 | kavieng
# Processing Record 340 of Set 7 | pella
# Processing Record 341 of Set 7 | vera cruz
# Processing Record 342 of Set 7 | avera
# Processing Record 343 of Set 7 | faanui
# Processing Record 344 of Set 7 | samur
# Processing Record 345 of Set 7 | luderitz
# Processing Record 346 of Set 7 | cururupu
# Processing Record 347 of Set 7 | yam
# Processing Record 348 of Set 7 | biloxi
# Processing Record 349 of Set 7 | okhotsk
# Processing Record 350 of Set 7 | greytown
# Processing Record 351 of Set 7 | chokwe
# Processing Record 352 of Set 7 | ankang
# Processing Record 353 of Set 7 | port macquarie
# Processing Record 354 of Set 7 | bubaque
# Processing Record 355 of Set 7 | tazovskiy
# Processing Record 356 of Set 7 | byron bay
# Processing Record 358 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 359 of Set 8 | lorengau
# Processing Record 360 of Set 8 | paamiut
# Processing Record 361 of Set 8 | bintulu
# Processing Record 362 of Set 8 | hirara
# Processing Record 363 of Set 8 | negombo
# Processing Record 364 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 365 of Set 8 | baghdad
# Processing Record 366 of Set 8 | greenwood
# Processing Record 367 of Set 8 | ixtapa
# Processing Record 368 of Set 8 | vaasa
# Processing Record 369 of Set 8 | blagoyevo
# Processing Record 370 of Set 8 | de-kastri
# Processing Record 371 of Set 8 | pierre
# Processing Record 372 of Set 8 | bor
# Processing Record 373 of Set 8 | necochea
# Processing Record 374 of Set 8 | zhaotong
# Processing Record 375 of Set 8 | itarema
# Processing Record 376 of Set 8 | kavaratti
# Processing Record 377 of Set 8 | placido de castro
# Processing Record 378 of Set 8 | goderich
# Processing Record 379 of Set 8 | kasongo-lunda
# Processing Record 380 of Set 8 | bandarbeyla
# Processing Record 381 of Set 8 | sao joao da barra
# Processing Record 382 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 383 of Set 8 | matay
# Processing Record 384 of Set 8 | edd
# Processing Record 385 of Set 8 | ulaanbaatar
# Processing Record 386 of Set 8 | saint-georges
# Processing Record 387 of Set 8 | srednekolymsk
# Processing Record 388 of Set 8 | aguai
# Processing Record 389 of Set 8 | zolotinka
# City not found. Skipping...
# Processing Record 390 of Set 8 | norman wells
# Processing Record 391 of Set 8 | iralaya
# Processing Record 392 of Set 8 | kharp
# Processing Record 393 of Set 8 | volchanets
# Processing Record 394 of Set 8 | svetlyy
# Processing Record 395 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 396 of Set 8 | narsaq
# Processing Record 397 of Set 8 | bengkulu
# Processing Record 398 of Set 8 | humboldt
# Processing Record 399 of Set 8 | buala
# Processing Record 400 of Set 8 | puerto quijarro
# Processing Record 401 of Set 8 | baykit
# Processing Record 402 of Set 8 | katsuura
# Processing Record 403 of Set 8 | kailua
# Processing Record 404 of Set 8 | vostok
# Processing Record 405 of Set 8 | yagodnoye
# Processing Record 406 of Set 8 | rosetown
# Processing Record 407 of Set 8 | rawson
# Processing Record 409 of Set 9 | kalmunai
# Processing Record 410 of Set 9 | yangshe
# Processing Record 411 of Set 9 | liku
# Processing Record 412 of Set 9 | nyurba
# Processing Record 413 of Set 9 | monastyrishche
# Processing Record 414 of Set 9 | kapuskasing
# Processing Record 415 of Set 9 | iquitos
# Processing Record 416 of Set 9 | kuusamo
# Processing Record 417 of Set 9 | raga
# Processing Record 418 of Set 9 | kaduna
# Processing Record 419 of Set 9 | kaitangata
# Processing Record 420 of Set 9 | abu kamal
# Processing Record 421 of Set 9 | russell
# Processing Record 422 of Set 9 | isangel
# Processing Record 423 of Set 9 | monte alegre
# Processing Record 424 of Set 9 | guiglo
# Processing Record 425 of Set 9 | anloga
# Processing Record 426 of Set 9 | turukhansk
# Processing Record 427 of Set 9 | geraldton
# Processing Record 428 of Set 9 | letnyaya stavka
# Processing Record 429 of Set 9 | scottsbluff
# Processing Record 430 of Set 9 | gillette
# Processing Record 431 of Set 9 | yaan
# Processing Record 432 of Set 9 | carsamba
# Processing Record 433 of Set 9 | marsh harbour
# Processing Record 434 of Set 9 | ternate
# Processing Record 435 of Set 9 | buchanan
# Processing Record 436 of Set 9 | krasnoselkup
# Processing Record 437 of Set 9 | pachino
# Processing Record 438 of Set 9 | hay river
# Processing Record 439 of Set 9 | khiri mat
# Processing Record 440 of Set 9 | quinta do anjo
# Processing Record 441 of Set 9 | navolato
# Processing Record 442 of Set 9 | dubasari
# Processing Record 443 of Set 9 | rudarpur
# Processing Record 444 of Set 9 | abu samrah
# Processing Record 445 of Set 9 | derzhavinsk
# Processing Record 446 of Set 9 | rocha
# Processing Record 447 of Set 9 | colares
# Processing Record 448 of Set 9 | acobamba
# Processing Record 449 of Set 9 | yangjiang
# Processing Record 450 of Set 9 | lena
# Processing Record 451 of Set 9 | limon
# Processing Record 452 of Set 9 | stony plain
# Processing Record 453 of Set 9 | khartoum
# Processing Record 454 of Set 9 | murmashi
# Processing Record 455 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 456 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 457 of Set 9 | plettenberg bay
# Processing Record 458 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 460 of Set 10 | chekhov
# Processing Record 461 of Set 10 | bathsheba
# Processing Record 462 of Set 10 | uvalde
# Processing Record 463 of Set 10 | evensk
# Processing Record 464 of Set 10 | sandwick
# Processing Record 465 of Set 10 | mullovka
# Processing Record 466 of Set 10 | nizwa
# Processing Record 467 of Set 10 | saquarema
# Processing Record 468 of Set 10 | muzaffarpur
# Processing Record 469 of Set 10 | taltal
# Processing Record 470 of Set 10 | payo
# Processing Record 471 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 472 of Set 10 | tyubuk
# Processing Record 473 of Set 10 | primorskiy
# Processing Record 474 of Set 10 | najran
# Processing Record 475 of Set 10 | ojinaga
# Processing Record 476 of Set 10 | saint-augustin
# Processing Record 477 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 478 of Set 10 | dongsheng
# Processing Record 479 of Set 10 | muros
# Processing Record 480 of Set 10 | mackay
# Processing Record 481 of Set 10 | sabha
# Processing Record 482 of Set 10 | casa grande
# Processing Record 483 of Set 10 | mayakonda
# Processing Record 484 of Set 10 | kangaatsiaq
# Processing Record 485 of Set 10 | kurchum
# Processing Record 486 of Set 10 | nhulunbuy
# Processing Record 487 of Set 10 | gizo
# Processing Record 488 of Set 10 | lac du bonnet
# Processing Record 489 of Set 10 | malanje
# Processing Record 490 of Set 10 | kaardi
# City not found. Skipping...
# Processing Record 491 of Set 10 | brekstad
# Processing Record 492 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 493 of Set 10 | mvangue
# Processing Record 494 of Set 10 | shizunai
# Processing Record 495 of Set 10 | ankazoabo
# Processing Record 496 of Set 10 | adrar
# Processing Record 497 of Set 10 | concordia
# Processing Record 498 of Set 10 | helong
# Processing Record 499 of Set 10 | tiznit
# Processing Record 500 of Set 10 | hasaki
# Processing Record 501 of Set 10 | nueve de julio
# Processing Record 502 of Set 10 | vrises
# Processing Record 503 of Set 10 | dekar
# Processing Record 504 of Set 10 | ouesso
# Processing Record 505 of Set 10 | verkhnyaya inta
# Processing Record 506 of Set 10 | vrangel
# Processing Record 507 of Set 10 | klaksvik
# Processing Record 508 of Set 10 | moyale
# Processing Record 509 of Set 10 | verkhnetulomskiy
# Processing Record 511 of Set 11 | mandalgovi
# Processing Record 512 of Set 11 | florence
# Processing Record 513 of Set 11 | presidencia roque saenz pena
# Processing Record 514 of Set 11 | burnie
# Processing Record 515 of Set 11 | igrim
# Processing Record 516 of Set 11 | ipixuna
# Processing Record 517 of Set 11 | nouakchott
# Processing Record 518 of Set 11 | great yarmouth
# Processing Record 519 of Set 11 | mikkeli
# Processing Record 520 of Set 11 | konganapuram
# Processing Record 521 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 522 of Set 11 | sovetsk
# Processing Record 523 of Set 11 | veshenskaya
# Processing Record 524 of Set 11 | campbell river
# Processing Record 525 of Set 11 | malakal
# Processing Record 526 of Set 11 | samarai
# Processing Record 527 of Set 11 | hamilton
# Processing Record 528 of Set 11 | armidale
# Processing Record 529 of Set 11 | moindou
# Processing Record 530 of Set 11 | udachnyy
# Processing Record 531 of Set 11 | waterbury
# Processing Record 532 of Set 11 | mahajanga
# Processing Record 533 of Set 11 | talnakh
# Processing Record 534 of Set 11 | erie
# Processing Record 535 of Set 11 | sorland
# Processing Record 536 of Set 11 | kupang
# Processing Record 537 of Set 11 | reconquista
# Processing Record 538 of Set 11 | hervey bay
# Processing Record 539 of Set 11 | bella vista
# Processing Record 540 of Set 11 | pacific grove
# Processing Record 541 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 542 of Set 11 | ngunguru
# Processing Record 543 of Set 11 | matveyevka
# Processing Record 544 of Set 11 | novaya zaimka
# Processing Record 545 of Set 11 | camacha
# Processing Record 546 of Set 11 | galle
# Processing Record 547 of Set 11 | khasan
# Processing Record 548 of Set 11 | dustlik
# Processing Record 549 of Set 11 | devonport
# Processing Record 550 of Set 11 | arrifes
# Processing Record 551 of Set 11 | miyang
# Processing Record 552 of Set 11 | auki
# Processing Record 553 of Set 11 | yantal
# Processing Record 554 of Set 11 | garmsar
# Processing Record 555 of Set 11 | jaumave
# Processing Record 556 of Set 11 | vallenar
# Processing Record 557 of Set 11 | kuzovatovo
# Processing Record 558 of Set 11 | woodward
# Processing Record 559 of Set 11 | caravelas
# Processing Record 560 of Set 11 | yuzhno-sukhokumsk
# Processing Record 562 of Set 12 | mayumba
# Processing Record 563 of Set 12 | bairiki
# Processing Record 564 of Set 12 | longuenesse
# Processing Record 565 of Set 12 | tzucacab
# Processing Record 566 of Set 12 | moroni
# Processing Record 567 of Set 12 | meadow lake
# Processing Record 568 of Set 12 | puri
# Processing Record 569 of Set 12 | honningsvag
# Processing Record 570 of Set 12 | banda aceh
# Processing Record 571 of Set 12 | biak
# Processing Record 572 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 573 of Set 12 | kysyl-syr
# Processing Record 574 of Set 12 | clyde river
# Processing Record 575 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 576 of Set 12 | darhan
# Processing Record 577 of Set 12 | darnah
# Processing Record 578 of Set 12 | bull savanna
# Processing Record 579 of Set 12 | kyaikkami
# Processing Record 580 of Set 12 | omboue
# Processing Record 581 of Set 12 | margate
# Processing Record 582 of Set 12 | ulundi
# Processing Record 583 of Set 12 | broken hill
# Processing Record 584 of Set 12 | roald
# Processing Record 585 of Set 12 | barroualie
# City not found. Skipping...
# Processing Record 586 of Set 12 | takoradi
# Processing Record 587 of Set 12 | ndele
# Processing Record 588 of Set 12 | beaverton
# Processing Record 589 of Set 12 | lubango
# Processing Record 590 of Set 12 | gorontalo
# Processing Record 591 of Set 12 | pangnirtung
# Processing Record 592 of Set 12 | portland
# Processing Record 593 of Set 12 | songjianghe
# Processing Record 594 of Set 12 | darfo
# Processing Record 595 of Set 12 | jinka
# Processing Record 596 of Set 12 | sakaiminato
# Processing Record 597 of Set 12 | christchurch
# Processing Record 598 of Set 12 | traunreut
# Processing Record 599 of Set 12 | vila franca do campo
# Processing Record 600 of Set 12 | ewa beach
# Processing Record 601 of Set 12 | poronaysk
# Processing Record 602 of Set 12 | belmonte
# Processing Record 603 of Set 12 | villarrica
# Processing Record 604 of Set 12 | cabedelo
# Processing Record 605 of Set 12 | lamont
# Processing Record 606 of Set 12 | shakiso
# Processing Record 607 of Set 12 | ningxiang
# Processing Record 608 of Set 12 | rolim de moura
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Punta Arenas -53.1500 -53.1500     51.91        62          75        8.05
# 1       Clinton  42.5870  42.5870     35.94        80          20        4.00
# 2    Lavrentiya  65.5833  65.5833    -14.13        87           2        8.77
# 3     Busselton -33.6500 -33.6500     69.49        44          77       13.51
# 4       Qaanaaq  77.4840  77.4840      2.89        76          69        7.47
# 5       Aquiraz  -3.9014  -3.9014     83.21        70          37        9.26
# 6     Upernavik  72.7868  72.7868     22.62        86          98        4.85
# 7    Codrington -38.2667 -38.2667     67.66        67           7       13.33
# 8      Yar-Sale  66.8333  66.8333     -1.17        99         100        9.60
# 9       Rikitea -23.1203 -23.1203     76.24        77           0       21.47
#
#   Country                 Date
# 0      CL  2021-12-01 03:45:34
# 1      US  2021-12-01 03:48:43
# 2      RU  2021-12-01 03:48:43
# 3      AU  2021-12-01 03:45:42
# 4      GL  2021-12-01 03:48:44
# 5      BR  2021-12-01 03:44:11
# 6      GL  2021-12-01 03:46:39
# 7      AU  2021-12-01 03:48:45
# 8      RU  2021-12-01 03:48:45
# 9      PF  2021-12-01 03:47:23

# %%
new_column = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# %%
city_data_df=city_data_df[new_column]
city_data_df
# Out:
#              City Country                 Date      Lat      Lng  Max Temp  \
# 0    Punta Arenas      CL  2021-12-01 03:45:34 -53.1500 -53.1500     51.91
# 1         Clinton      US  2021-12-01 03:48:43  42.5870  42.5870     35.94
# 2      Lavrentiya      RU  2021-12-01 03:48:43  65.5833  65.5833    -14.13
# 3       Busselton      AU  2021-12-01 03:45:42 -33.6500 -33.6500     69.49
# 4         Qaanaaq      GL  2021-12-01 03:48:44  77.4840  77.4840      2.89
# ..            ...     ...                  ...      ...      ...       ...
# 544    Villarrica      PY  2021-12-01 04:03:55 -25.7500 -25.7500     62.73
# 545      Cabedelo      BR  2021-12-01 04:03:56  -6.9811  -6.9811     77.67
# 546        Lamont      US  2021-12-01 04:03:56  35.2597  35.2597     75.79
# 547       Shakiso      ET  2021-12-01 04:03:57   5.7500   5.7500     52.95
# 548     Ningxiang      CN  2021-12-01 04:03:57  37.3400  37.3400     29.52
#
#      Humidity  Cloudiness  Wind Speed
# 0          62          75        8.05
# 1          80          20        4.00
# 2          87           2        8.77
# 3          44          77       13.51
# 4          76          69        7.47
# ..        ...         ...         ...
# 544        67           0        3.60
# 545        77          58       10.96
# 546        57           0        0.81
# 547        58          97        3.94
# 548        24          53        7.47
#
# [549 rows x 9 columns]

# %%
save_data_tocsv = "weather_data/cities.csv"
#export data to CSV
city_data_df.to_csv(save_data_tocsv,index_label="City_ID")
city_data_df
# Out:
#              City Country                 Date      Lat      Lng  Max Temp  \
# 0    Punta Arenas      CL  2021-12-01 03:45:34 -53.1500 -53.1500     51.91
# 1         Clinton      US  2021-12-01 03:48:43  42.5870  42.5870     35.94
# 2      Lavrentiya      RU  2021-12-01 03:48:43  65.5833  65.5833    -14.13
# 3       Busselton      AU  2021-12-01 03:45:42 -33.6500 -33.6500     69.49
# 4         Qaanaaq      GL  2021-12-01 03:48:44  77.4840  77.4840      2.89
# ..            ...     ...                  ...      ...      ...       ...
# 544    Villarrica      PY  2021-12-01 04:03:55 -25.7500 -25.7500     62.73
# 545      Cabedelo      BR  2021-12-01 04:03:56  -6.9811  -6.9811     77.67
# 546        Lamont      US  2021-12-01 04:03:56  35.2597  35.2597     75.79
# 547       Shakiso      ET  2021-12-01 04:03:57   5.7500   5.7500     52.95
# 548     Ningxiang      CN  2021-12-01 04:03:57  37.3400  37.3400     29.52
#
#      Humidity  Cloudiness  Wind Speed
# 0          62          75        8.05
# 1          80          20        4.00
# 2          87           2        8.77
# 3          44          77       13.51
# 4          76          69        7.47
# ..        ...         ...         ...
# 544        67           0        3.60
# 545        77          58       10.96
# 546        57           0        0.81
# 547        58          97        3.94
# 548        24          53        7.47
#
# [549 rows x 9 columns]

# %%
#Extract field for plotting
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
import time
today = time.strftime("%x")
today
# Out:
# '11/30/21'

# %%
import time
plt.scatter(lats,
            max_temps,
            edgecolor="black",linewidths=1,marker="o",alpha=0.8,label="Cities")
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()
plt.savefig("weather_data/Fig1.png")

# %%
plt.scatter(lats,
            humidity,
            edgecolors="black",linewidths=1,alpha=0.8,marker = "o",label = "Cities")
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
