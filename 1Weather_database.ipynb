# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
from citipy import citipy
import time
from datetime import datetime
from config import weather_api_key
import numpy as np

# %%
lats = np.random.uniform(low = -90.000, high = 90.000, size = 1500)
langs = np.random.uniform(low = -180.000, high = 180.000, size = 1500)
lat_langs = zip(lats, langs)
lat_langs
coordinates = list(lat_langs)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
clean_cities =[]
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in clean_cities:
        clean_cities.append(city)

# %%
# create an empty list to hold the weather data
city_data = []
# Print the begining of the logging
print("Begining Data Retrieval     ")
print("____________________________")

#create counters
record_count = 1
set_count = 1

for i, city in enumerate(clean_cities):
    #group cities
    if (i % 50 == 0 and i >=50):
        set_count +=1
        record_count +=1
        time.sleep(60)
    #create and endpoint URL
    city_url = url +"&q="+ city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count+=1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lat"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except Exception as e:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Begining Data Retrieval
# ____________________________
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | naron
# Processing Record 3 of Set 1 | broome
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | presidencia roque saenz pena
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 1 | scarborough
# Processing Record 10 of Set 1 | luwingu
# Processing Record 11 of Set 1 | quatre cocos
# Processing Record 12 of Set 1 | bacolod
# Processing Record 13 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 1 | alofi
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | kihei
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | sitka
# Processing Record 21 of Set 1 | san policarpo
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | ambilobe
# Processing Record 24 of Set 1 | luderitz
# Processing Record 25 of Set 1 | talnakh
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | knysna
# Processing Record 28 of Set 1 | novorzhev
# Processing Record 29 of Set 1 | ingham
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | turayf
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | kaitangata
# Processing Record 35 of Set 1 | rocha
# Processing Record 36 of Set 1 | utraula
# Processing Record 37 of Set 1 | vao
# Processing Record 38 of Set 1 | iqaluit
# Processing Record 39 of Set 1 | san luis
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | east london
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | shache
# Processing Record 44 of Set 1 | pevek
# Processing Record 45 of Set 1 | hvammstangi
# City not found. Skipping...
# Processing Record 46 of Set 1 | kisangani
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 1 | mokolo
# Processing Record 52 of Set 2 | kudahuvadhoo
# Processing Record 53 of Set 2 | toamasina
# Processing Record 54 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 55 of Set 2 | nyagan
# Processing Record 56 of Set 2 | rocky mountain house
# Processing Record 57 of Set 2 | thompson
# Processing Record 58 of Set 2 | kapaa
# Processing Record 59 of Set 2 | carnarvon
# Processing Record 60 of Set 2 | ponta do sol
# Processing Record 61 of Set 2 | mahebourg
# Processing Record 62 of Set 2 | miraflores
# Processing Record 63 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 64 of Set 2 | castro
# Processing Record 65 of Set 2 | gizo
# Processing Record 66 of Set 2 | albany
# Processing Record 67 of Set 2 | newcastle
# Processing Record 68 of Set 2 | smithers
# Processing Record 69 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 70 of Set 2 | roma
# Processing Record 71 of Set 2 | formosa
# Processing Record 72 of Set 2 | muravlenko
# Processing Record 73 of Set 2 | bakel
# Processing Record 74 of Set 2 | corinto
# Processing Record 75 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 76 of Set 2 | eureka
# Processing Record 77 of Set 2 | haines junction
# Processing Record 78 of Set 2 | hilo
# Processing Record 79 of Set 2 | santa maria
# Processing Record 80 of Set 2 | viedma
# Processing Record 81 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 82 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 83 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 84 of Set 2 | ust-maya
# Processing Record 85 of Set 2 | chuy
# Processing Record 86 of Set 2 | bredasdorp
# Processing Record 87 of Set 2 | labuan
# Processing Record 88 of Set 2 | puerto ayora
# Processing Record 89 of Set 2 | norman wells
# Processing Record 90 of Set 2 | saldanha
# Processing Record 91 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 92 of Set 2 | ushuaia
# Processing Record 93 of Set 2 | tharad
# Processing Record 94 of Set 2 | bethel
# Processing Record 95 of Set 2 | isangel
# Processing Record 96 of Set 2 | berlevag
# Processing Record 97 of Set 2 | sarangani
# Processing Record 98 of Set 2 | mount isa
# Processing Record 99 of Set 2 | ishigaki
# Processing Record 100 of Set 2 | ewa beach
# Processing Record 101 of Set 2 | namatanai
# Processing Record 103 of Set 3 | tumaco
# Processing Record 104 of Set 3 | ancud
# Processing Record 105 of Set 3 | provideniya
# Processing Record 106 of Set 3 | ushtobe
# Processing Record 107 of Set 3 | ucluelet
# Processing Record 108 of Set 3 | rundu
# Processing Record 109 of Set 3 | rumoi
# Processing Record 110 of Set 3 | setermoen
# Processing Record 111 of Set 3 | aklavik
# Processing Record 112 of Set 3 | port lincoln
# Processing Record 113 of Set 3 | flinders
# Processing Record 114 of Set 3 | kavieng
# Processing Record 115 of Set 3 | nanortalik
# Processing Record 116 of Set 3 | aguimes
# Processing Record 117 of Set 3 | qaanaaq
# Processing Record 118 of Set 3 | quballat
# Processing Record 119 of Set 3 | lompoc
# Processing Record 120 of Set 3 | amparafaravola
# Processing Record 121 of Set 3 | belize
# Processing Record 122 of Set 3 | torbay
# Processing Record 123 of Set 3 | bengkulu
# Processing Record 124 of Set 3 | clyde river
# Processing Record 125 of Set 3 | naftah
# City not found. Skipping...
# Processing Record 126 of Set 3 | belmonte
# Processing Record 127 of Set 3 | bowen
# Processing Record 128 of Set 3 | mayo
# Processing Record 129 of Set 3 | jining
# Processing Record 130 of Set 3 | kodiak
# Processing Record 131 of Set 3 | vaini
# Processing Record 132 of Set 3 | banjar
# Processing Record 133 of Set 3 | grand baie
# Processing Record 134 of Set 3 | upernavik
# Processing Record 135 of Set 3 | katangli
# Processing Record 136 of Set 3 | butaritari
# Processing Record 137 of Set 3 | mehamn
# Processing Record 138 of Set 3 | lebu
# Processing Record 139 of Set 3 | deputatskiy
# Processing Record 140 of Set 3 | touros
# Processing Record 141 of Set 3 | urusha
# Processing Record 142 of Set 3 | vestmannaeyjar
# Processing Record 143 of Set 3 | busselton
# Processing Record 144 of Set 3 | esperance
# Processing Record 145 of Set 3 | hithadhoo
# Processing Record 146 of Set 3 | port alfred
# Processing Record 147 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 148 of Set 3 | taksimo
# Processing Record 149 of Set 3 | tual
# Processing Record 150 of Set 3 | tanushimaru
# Processing Record 151 of Set 3 | shimoda
# Processing Record 152 of Set 3 | pangnirtung
# Processing Record 154 of Set 4 | constitucion
# Processing Record 155 of Set 4 | aksarka
# Processing Record 156 of Set 4 | weligama
# Processing Record 157 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 158 of Set 4 | najran
# Processing Record 159 of Set 4 | auki
# Processing Record 160 of Set 4 | zabol
# Processing Record 161 of Set 4 | arraial do cabo
# Processing Record 162 of Set 4 | harper
# Processing Record 163 of Set 4 | ribeira grande
# Processing Record 164 of Set 4 | sao joao da barra
# Processing Record 165 of Set 4 | longyearbyen
# Processing Record 166 of Set 4 | tigil
# Processing Record 167 of Set 4 | mogadishu
# Processing Record 168 of Set 4 | kansk
# Processing Record 169 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 170 of Set 4 | ilulissat
# Processing Record 171 of Set 4 | bud
# Processing Record 172 of Set 4 | port hardy
# Processing Record 173 of Set 4 | saskylakh
# Processing Record 174 of Set 4 | nago
# Processing Record 175 of Set 4 | cherskiy
# Processing Record 176 of Set 4 | jawhar
# Processing Record 177 of Set 4 | narsaq
# Processing Record 178 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 179 of Set 4 | pisco
# Processing Record 180 of Set 4 | svetlogorsk
# Processing Record 181 of Set 4 | dikson
# Processing Record 182 of Set 4 | new norfolk
# Processing Record 183 of Set 4 | todos santos
# Processing Record 184 of Set 4 | pecos
# Processing Record 185 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 186 of Set 4 | moose factory
# Processing Record 187 of Set 4 | kawalu
# Processing Record 188 of Set 4 | hobyo
# Processing Record 189 of Set 4 | tabou
# Processing Record 190 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 191 of Set 4 | kahului
# Processing Record 192 of Set 4 | seoul
# Processing Record 193 of Set 4 | ovalle
# Processing Record 194 of Set 4 | pula
# Processing Record 195 of Set 4 | maceio
# Processing Record 196 of Set 4 | pacific grove
# Processing Record 197 of Set 4 | novaya mayna
# Processing Record 198 of Set 4 | axim
# Processing Record 199 of Set 4 | aquiraz
# Processing Record 200 of Set 4 | parauna
# Processing Record 201 of Set 4 | tuatapere
# Processing Record 202 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 203 of Set 4 | mananjary
# Processing Record 205 of Set 5 | gigmoto
# Processing Record 206 of Set 5 | thermon
# City not found. Skipping...
# Processing Record 207 of Set 5 | martapura
# Processing Record 208 of Set 5 | marsh harbour
# Processing Record 209 of Set 5 | namibe
# Processing Record 210 of Set 5 | high level
# Processing Record 211 of Set 5 | mount gambier
# Processing Record 212 of Set 5 | stokmarknes
# Processing Record 213 of Set 5 | brainerd
# Processing Record 214 of Set 5 | svecha
# Processing Record 215 of Set 5 | atuona
# Processing Record 216 of Set 5 | taoudenni
# Processing Record 217 of Set 5 | tautira
# Processing Record 218 of Set 5 | miandrivazo
# Processing Record 219 of Set 5 | buraydah
# Processing Record 220 of Set 5 | cidreira
# Processing Record 221 of Set 5 | tomball
# Processing Record 222 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 223 of Set 5 | mahenge
# Processing Record 224 of Set 5 | sembakung
# Processing Record 225 of Set 5 | krasnyy kut
# Processing Record 226 of Set 5 | goudomp
# City not found. Skipping...
# Processing Record 227 of Set 5 | montepuez
# Processing Record 228 of Set 5 | forestville
# Processing Record 229 of Set 5 | tiksi
# Processing Record 230 of Set 5 | vysokogornyy
# Processing Record 231 of Set 5 | hofn
# Processing Record 232 of Set 5 | thiruvananthapuram
# Processing Record 233 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 234 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 235 of Set 5 | luanda
# Processing Record 236 of Set 5 | bristol
# Processing Record 237 of Set 5 | santa rosa
# Processing Record 238 of Set 5 | beroroha
# Processing Record 239 of Set 5 | russell
# Processing Record 240 of Set 5 | izmit
# Processing Record 241 of Set 5 | saint-pierre
# Processing Record 242 of Set 5 | coihaique
# Processing Record 243 of Set 5 | talara
# Processing Record 244 of Set 5 | chihuahua
# Processing Record 245 of Set 5 | macau
# Processing Record 246 of Set 5 | warmbad
# Processing Record 247 of Set 5 | north bend
# Processing Record 248 of Set 5 | ostrovnoy
# Processing Record 249 of Set 5 | boundiali
# Processing Record 250 of Set 5 | san jeronimo
# Processing Record 251 of Set 5 | nalut
# Processing Record 252 of Set 5 | sorong
# Processing Record 253 of Set 5 | basoko
# Processing Record 254 of Set 5 | zhangye
# Processing Record 256 of Set 6 | stolin
# Processing Record 257 of Set 6 | geraldton
# Processing Record 258 of Set 6 | vostok
# Processing Record 259 of Set 6 | lufilufi
# Processing Record 260 of Set 6 | havelock
# Processing Record 261 of Set 6 | dingle
# Processing Record 262 of Set 6 | gibara
# Processing Record 263 of Set 6 | sovetskiy
# Processing Record 264 of Set 6 | tapaua
# City not found. Skipping...
# Processing Record 265 of Set 6 | adil-yangiyurt
# Processing Record 266 of Set 6 | jardim
# Processing Record 267 of Set 6 | rudbar
# Processing Record 268 of Set 6 | kirksville
# Processing Record 269 of Set 6 | leningradskiy
# Processing Record 270 of Set 6 | talcahuano
# Processing Record 271 of Set 6 | yar-sale
# Processing Record 272 of Set 6 | gimli
# Processing Record 273 of Set 6 | hambantota
# Processing Record 274 of Set 6 | nouadhibou
# Processing Record 275 of Set 6 | codrington
# Processing Record 276 of Set 6 | ossora
# Processing Record 277 of Set 6 | sal rei
# Processing Record 278 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 279 of Set 6 | esso
# Processing Record 280 of Set 6 | burica
# City not found. Skipping...
# Processing Record 281 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 282 of Set 6 | pokhara
# Processing Record 283 of Set 6 | dakar
# Processing Record 284 of Set 6 | kabanjahe
# Processing Record 285 of Set 6 | inongo
# Processing Record 286 of Set 6 | port elizabeth
# Processing Record 287 of Set 6 | brae
# Processing Record 288 of Set 6 | the valley
# Processing Record 289 of Set 6 | badou
# Processing Record 290 of Set 6 | marquette
# Processing Record 291 of Set 6 | saint george
# Processing Record 292 of Set 6 | tansen
# Processing Record 293 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 294 of Set 6 | dali
# Processing Record 295 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 296 of Set 6 | comodoro rivadavia
# Processing Record 297 of Set 6 | puerto leguizamo
# Processing Record 298 of Set 6 | salamiyah
# Processing Record 299 of Set 6 | los llanos de aridane
# Processing Record 300 of Set 6 | bambous virieux
# Processing Record 301 of Set 6 | sakakah
# Processing Record 302 of Set 6 | ubinskoye
# Processing Record 303 of Set 6 | pahrump
# Processing Record 304 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 305 of Set 6 | aguadas
# Processing Record 307 of Set 7 | bandarbeyla
# Processing Record 308 of Set 7 | grindavik
# Processing Record 309 of Set 7 | srednekolymsk
# Processing Record 310 of Set 7 | avera
# Processing Record 311 of Set 7 | lasa
# Processing Record 312 of Set 7 | faanui
# Processing Record 313 of Set 7 | lorengau
# Processing Record 314 of Set 7 | cabo san lucas
# Processing Record 315 of Set 7 | hay river
# Processing Record 316 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 317 of Set 7 | adrar
# Processing Record 318 of Set 7 | hovd
# Processing Record 319 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 320 of Set 7 | vidim
# Processing Record 321 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 322 of Set 7 | sterling
# Processing Record 323 of Set 7 | mandalgovi
# Processing Record 324 of Set 7 | kaiserslautern
# Processing Record 325 of Set 7 | itupeva
# Processing Record 326 of Set 7 | kapuskasing
# Processing Record 327 of Set 7 | qasigiannguit
# Processing Record 328 of Set 7 | mitsamiouli
# Processing Record 329 of Set 7 | sola
# Processing Record 330 of Set 7 | matara
# Processing Record 331 of Set 7 | olafsvik
# Processing Record 332 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 333 of Set 7 | niquelandia
# Processing Record 334 of Set 7 | nantucket
# Processing Record 335 of Set 7 | jalu
# Processing Record 336 of Set 7 | medowie
# Processing Record 337 of Set 7 | karaton
# Processing Record 338 of Set 7 | gorom-gorom
# Processing Record 339 of Set 7 | kostino
# Processing Record 340 of Set 7 | roald
# Processing Record 341 of Set 7 | kruisfontein
# Processing Record 342 of Set 7 | nizhniy kuranakh
# Processing Record 343 of Set 7 | colombia
# Processing Record 344 of Set 7 | limoux
# Processing Record 345 of Set 7 | morro bay
# Processing Record 346 of Set 7 | bolgar
# Processing Record 347 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 348 of Set 7 | lukovetskiy
# Processing Record 349 of Set 7 | tura
# Processing Record 350 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 351 of Set 7 | egvekinot
# Processing Record 352 of Set 7 | marathon
# Processing Record 353 of Set 7 | benghazi
# Processing Record 354 of Set 7 | kovdor
# Processing Record 355 of Set 7 | severo-kurilsk
# Processing Record 356 of Set 7 | bousse
# Processing Record 358 of Set 8 | san francisco
# Processing Record 359 of Set 8 | sao filipe
# Processing Record 360 of Set 8 | nirasaki
# Processing Record 361 of Set 8 | pangody
# Processing Record 362 of Set 8 | itoman
# Processing Record 363 of Set 8 | okha
# Processing Record 364 of Set 8 | simao
# Processing Record 365 of Set 8 | puerto escondido
# Processing Record 366 of Set 8 | riyadh
# Processing Record 367 of Set 8 | odessa
# Processing Record 368 of Set 8 | manzhouli
# Processing Record 369 of Set 8 | chumphon
# Processing Record 370 of Set 8 | warrington
# Processing Record 371 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 372 of Set 8 | isernia
# Processing Record 373 of Set 8 | chokurdakh
# Processing Record 374 of Set 8 | le passage
# Processing Record 375 of Set 8 | westport
# Processing Record 376 of Set 8 | husavik
# Processing Record 377 of Set 8 | vila franca do campo
# Processing Record 378 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 379 of Set 8 | victoria
# Processing Record 380 of Set 8 | makokou
# Processing Record 381 of Set 8 | rio gallegos
# Processing Record 382 of Set 8 | camocim
# Processing Record 383 of Set 8 | souillac
# Processing Record 384 of Set 8 | fort nelson
# Processing Record 385 of Set 8 | marrakesh
# Processing Record 386 of Set 8 | sur
# Processing Record 387 of Set 8 | te anau
# Processing Record 388 of Set 8 | cayenne
# Processing Record 389 of Set 8 | stykkisholmur
# Processing Record 390 of Set 8 | kayerkan
# Processing Record 391 of Set 8 | caapucu
# Processing Record 392 of Set 8 | gasa
# Processing Record 393 of Set 8 | marawi
# Processing Record 394 of Set 8 | guerrero
# Processing Record 395 of Set 8 | flagstaff
# Processing Record 396 of Set 8 | kasongo-lunda
# Processing Record 397 of Set 8 | bati
# Processing Record 398 of Set 8 | okrika
# Processing Record 399 of Set 8 | unye
# City not found. Skipping...
# Processing Record 400 of Set 8 | grand gaube
# Processing Record 401 of Set 8 | hoquiam
# Processing Record 402 of Set 8 | tacuarembo
# Processing Record 403 of Set 8 | podgorenskiy
# Processing Record 404 of Set 8 | airai
# Processing Record 405 of Set 8 | la paz
# Processing Record 406 of Set 8 | aksu
# Processing Record 407 of Set 8 | pasighat
# Processing Record 409 of Set 9 | alihe
# Processing Record 410 of Set 9 | ipoh
# Processing Record 411 of Set 9 | lenger
# Processing Record 412 of Set 9 | san lorenzo
# Processing Record 413 of Set 9 | beni suef
# Processing Record 414 of Set 9 | palmer
# Processing Record 415 of Set 9 | nishihara
# Processing Record 416 of Set 9 | luba
# Processing Record 417 of Set 9 | porto novo
# Processing Record 418 of Set 9 | hamilton
# Processing Record 419 of Set 9 | conceicao do araguaia
# Processing Record 420 of Set 9 | ayan
# Processing Record 421 of Set 9 | hailar
# Processing Record 422 of Set 9 | jambi
# Processing Record 423 of Set 9 | jacareacanga
# Processing Record 424 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 425 of Set 9 | ilave
# Processing Record 426 of Set 9 | luang prabang
# Processing Record 427 of Set 9 | lethem
# Processing Record 428 of Set 9 | pathein
# Processing Record 429 of Set 9 | spassk-ryazanskiy
# Processing Record 430 of Set 9 | swift current
# Processing Record 431 of Set 9 | kodinsk
# Processing Record 432 of Set 9 | merke
# Processing Record 433 of Set 9 | ahumada
# City not found. Skipping...
# Processing Record 434 of Set 9 | tilichiki
# Processing Record 435 of Set 9 | dakoro
# Processing Record 436 of Set 9 | beringovskiy
# Processing Record 437 of Set 9 | paamiut
# Processing Record 438 of Set 9 | homer
# Processing Record 439 of Set 9 | tomatlan
# Processing Record 440 of Set 9 | skaudvile
# Processing Record 441 of Set 9 | klaksvik
# Processing Record 442 of Set 9 | saint-paul
# Processing Record 443 of Set 9 | nikolskoye
# Processing Record 444 of Set 9 | vilyuysk
# Processing Record 445 of Set 9 | lavrentiya
# Processing Record 446 of Set 9 | rionegro
# Processing Record 447 of Set 9 | acapulco
# Processing Record 448 of Set 9 | acari
# Processing Record 449 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 450 of Set 9 | anloga
# Processing Record 451 of Set 9 | kirakira
# Processing Record 452 of Set 9 | lohja
# Processing Record 453 of Set 9 | san quintin
# Processing Record 454 of Set 9 | san patricio
# Processing Record 455 of Set 9 | reconquista
# Processing Record 456 of Set 9 | moanda
# Processing Record 457 of Set 9 | waynesville
# Processing Record 458 of Set 9 | domoni
# Processing Record 460 of Set 10 | mingguang
# Processing Record 461 of Set 10 | naze
# Processing Record 462 of Set 10 | west bay
# Processing Record 463 of Set 10 | coquimbo
# Processing Record 464 of Set 10 | tutoia
# Processing Record 465 of Set 10 | vardo
# Processing Record 466 of Set 10 | butka
# Processing Record 467 of Set 10 | katsuura
# Processing Record 468 of Set 10 | ust-kulom
# Processing Record 469 of Set 10 | paka
# Processing Record 470 of Set 10 | la brea
# Processing Record 471 of Set 10 | gat
# Processing Record 472 of Set 10 | conde
# Processing Record 473 of Set 10 | black river
# Processing Record 474 of Set 10 | livani
# Processing Record 475 of Set 10 | tornio
# Processing Record 476 of Set 10 | huangpu
# Processing Record 477 of Set 10 | manono
# Processing Record 478 of Set 10 | ayr
# Processing Record 479 of Set 10 | borovoy
# Processing Record 480 of Set 10 | yarada
# Processing Record 481 of Set 10 | swinoujscie
# Processing Record 482 of Set 10 | harsin
# Processing Record 483 of Set 10 | krasnoselkup
# Processing Record 484 of Set 10 | kiama
# Processing Record 485 of Set 10 | cervo
# Processing Record 486 of Set 10 | karratha
# Processing Record 487 of Set 10 | hagi
# Processing Record 488 of Set 10 | grootfontein
# Processing Record 489 of Set 10 | hasaki
# Processing Record 490 of Set 10 | itarema
# Processing Record 491 of Set 10 | mabaruma
# Processing Record 492 of Set 10 | okhotsk
# Processing Record 493 of Set 10 | rio grande
# Processing Record 494 of Set 10 | kununurra
# Processing Record 495 of Set 10 | asau
# Processing Record 496 of Set 10 | san andres
# Processing Record 497 of Set 10 | cairns
# Processing Record 498 of Set 10 | biella
# Processing Record 499 of Set 10 | barcarena
# Processing Record 500 of Set 10 | sechura
# Processing Record 501 of Set 10 | ilhabela
# Processing Record 502 of Set 10 | antsohihy
# Processing Record 503 of Set 10 | trinidad
# Processing Record 504 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 505 of Set 10 | honavar
# Processing Record 506 of Set 10 | shunyi
# Processing Record 507 of Set 10 | pervomayskiy
# Processing Record 508 of Set 10 | edd
# Processing Record 509 of Set 10 | tanete
# Processing Record 511 of Set 11 | kharp
# Processing Record 512 of Set 11 | ulaangom
# Processing Record 513 of Set 11 | northam
# Processing Record 514 of Set 11 | vredendal
# Processing Record 515 of Set 11 | vanimo
# Processing Record 516 of Set 11 | khonsa
# Processing Record 517 of Set 11 | hami
# Processing Record 518 of Set 11 | samarai
# Processing Record 519 of Set 11 | paredon
# Processing Record 520 of Set 11 | leshukonskoye
# Processing Record 521 of Set 11 | kattivakkam
# Processing Record 522 of Set 11 | bundaberg
# Processing Record 523 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 524 of Set 11 | almirante tamandare
# Processing Record 525 of Set 11 | richards bay
# Processing Record 526 of Set 11 | padang
# Processing Record 527 of Set 11 | dunmore town
# Processing Record 528 of Set 11 | yulara
# Processing Record 529 of Set 11 | lexington park
# Processing Record 530 of Set 11 | torbat-e jam
# Processing Record 531 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 532 of Set 11 | tezu
# Processing Record 533 of Set 11 | smiltene
# Processing Record 534 of Set 11 | prince rupert
# Processing Record 535 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 536 of Set 11 | mackenzie
# Processing Record 537 of Set 11 | bolivar
# Processing Record 538 of Set 11 | palamos
# Processing Record 539 of Set 11 | ziro
# Processing Record 540 of Set 11 | havoysund
# Processing Record 541 of Set 11 | vikhorevka
# Processing Record 542 of Set 11 | uyuni
# Processing Record 543 of Set 11 | da lat
# Processing Record 544 of Set 11 | simao dias
# Processing Record 545 of Set 11 | miri
# Processing Record 546 of Set 11 | kandri
# Processing Record 547 of Set 11 | chittaurgarh
# Processing Record 548 of Set 11 | anadyr
# Processing Record 549 of Set 11 | zhezkazgan
# Processing Record 550 of Set 11 | iquique
# Processing Record 551 of Set 11 | bilibino
# Processing Record 552 of Set 11 | sistranda
# Processing Record 553 of Set 11 | wanaka
# Processing Record 554 of Set 11 | atambua
# Processing Record 555 of Set 11 | takoradi
# Processing Record 556 of Set 11 | cap malheureux
# Processing Record 557 of Set 11 | ippy
# Processing Record 558 of Set 11 | qiongshan
# Processing Record 559 of Set 11 | christchurch
# Processing Record 560 of Set 11 | san angelo
# Processing Record 562 of Set 12 | rincon
# Processing Record 563 of Set 12 | matamoros
# Processing Record 564 of Set 12 | irbil
# Processing Record 565 of Set 12 | banda aceh
# Processing Record 566 of Set 12 | soe
# Processing Record 567 of Set 12 | shu
# Processing Record 568 of Set 12 | thinadhoo
# Processing Record 569 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 570 of Set 12 | sao pedro do sul
# Processing Record 571 of Set 12 | upata
# Processing Record 572 of Set 12 | port-gentil
# Processing Record 573 of Set 12 | manggar
# Processing Record 574 of Set 12 | iwanai
# Processing Record 575 of Set 12 | bella vista
# Processing Record 576 of Set 12 | san cristobal
# Processing Record 577 of Set 12 | pangai
# Processing Record 578 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 579 of Set 12 | lincoln
# Processing Record 580 of Set 12 | doka
# Processing Record 581 of Set 12 | nikki
# Processing Record 582 of Set 12 | chipinge
# Processing Record 583 of Set 12 | yongan
# Processing Record 584 of Set 12 | ginda
# Processing Record 585 of Set 12 | tabukiniberu
# City not found. Skipping...
# Processing Record 586 of Set 12 | salalah
# Processing Record 587 of Set 12 | humboldt
# Processing Record 588 of Set 12 | broken hill
# Processing Record 589 of Set 12 | oranjestad
# Processing Record 590 of Set 12 | bonaventure
# Processing Record 591 of Set 12 | ada
# Processing Record 592 of Set 12 | baykit
# Processing Record 593 of Set 12 | kollumerland
# City not found. Skipping...
# Processing Record 594 of Set 12 | zharkent
# Processing Record 595 of Set 12 | muroto
# Processing Record 596 of Set 12 | nelson bay
# Processing Record 597 of Set 12 | saint-augustin
# Processing Record 598 of Set 12 | lumut
# Processing Record 599 of Set 12 | bairiki
# Processing Record 600 of Set 12 | ferrol
# Processing Record 601 of Set 12 | podbelsk
# City not found. Skipping...
# Processing Record 602 of Set 12 | sao geraldo do araguaia
# Processing Record 603 of Set 12 | kavaratti
# Processing Record 604 of Set 12 | zhanjiang
# Processing Record 605 of Set 12 | chengde
# Processing Record 606 of Set 12 | odweyne
# Processing Record 607 of Set 12 | barcelos
# Processing Record 608 of Set 12 | laurel
# Processing Record 609 of Set 12 | acajutla
# Processing Record 610 of Set 12 | ambanja
# Processing Record 611 of Set 12 | malanville
# Processing Record 613 of Set 13 | aswan
# Processing Record 614 of Set 13 | pitsunda
# Processing Record 615 of Set 13 | straseni
# Processing Record 616 of Set 13 | karpathos
# Processing Record 617 of Set 13 | filingue
# Processing Record 618 of Set 13 | oranjemund
# Processing Record 619 of Set 13 | san ramon de la nueva oran
# Processing Record 620 of Set 13 | gold coast
# Processing Record 621 of Set 13 | palauig
# Processing Record 622 of Set 13 | carutapera
# Processing Record 623 of Set 13 | andarab
# City not found. Skipping...
# Processing Record 624 of Set 13 | mitchell
# Processing Record 625 of Set 13 | agadez
# Processing Record 626 of Set 13 | luangwa
# Processing Record 627 of Set 13 | mikun
# Processing Record 628 of Set 13 | san rafael
# Processing Record 629 of Set 13 | uskedal
# City not found. Skipping...
# Processing Record 630 of Set 13 | neiafu
# Processing Record 631 of Set 13 | guerrero negro
# Processing Record 632 of Set 13 | ketchikan
# Processing Record 633 of Set 13 | praia
# Processing Record 634 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 635 of Set 13 | micco
# Processing Record 636 of Set 13 | sao jose da coroa grande
# Processing Record 637 of Set 13 | oistins
# Processing Record 638 of Set 13 | saint-georges
# Processing Record 639 of Set 13 | falmouth
# Processing Record 640 of Set 13 | mana
# Processing Record 641 of Set 13 | teya
# Processing Record 642 of Set 13 | ha tinh
# Processing Record 643 of Set 13 | rawson
# Processing Record 644 of Set 13 | tandil
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                            City      Lat      Lng  Max Temp  Humidity  \
# 0                       Rikitea -23.1203 -23.1203     76.28        74
# 1                         Naron  43.5167  43.5167     54.01        78
# 2                        Broome  42.2506  42.2506     53.58        77
# 3                    Georgetown   5.4112   5.4112     77.90        89
# 4                     Jamestown  42.0970  42.0970     52.92        75
# 5  Presidencia Roque Saenz Pena -26.7852 -26.7852     91.17        29
# 6                        Avarua -21.2078 -21.2078     78.85        78
# 7                   Scarborough  54.2797  54.2797     35.53        82
# 8                       Luwingu -10.2621 -10.2621     72.34        48
# 9                  Quatre Cocos -20.2078 -20.2078     78.10        81
#
#    Cloudiness  Wind Speed Country                 Date
# 0           6       18.30      PF  2021-12-02 19:10:43
# 1          99       10.74      ES  2021-12-02 19:10:43
# 2          90        1.01      US  2021-12-02 19:10:44
# 3          40        3.44      MY  2021-12-02 19:09:15
# 4          90       10.00      US  2021-12-02 19:09:19
# 5           0        8.48      AR  2021-12-02 19:10:45
# 6          90       17.27      CK  2021-12-02 19:10:45
# 7         100        1.99      GB  2021-12-02 19:10:46
# 8         100        2.62      ZM  2021-12-02 19:10:47
# 9          30       12.50      MU  2021-12-02 19:09:58

# %%
new_column = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# %%
city_data_df=city_data_df[new_column]
city_data_df
# Out:
#            City Country                 Date      Lat      Lng  Max Temp  \
# 0       Rikitea      PF  2021-12-02 19:10:43 -23.1203 -23.1203     76.28
# 1         Naron      ES  2021-12-02 19:10:43  43.5167  43.5167     54.01
# 2        Broome      US  2021-12-02 19:10:44  42.2506  42.2506     53.58
# 3    Georgetown      MY  2021-12-02 19:09:15   5.4112   5.4112     77.90
# 4     Jamestown      US  2021-12-02 19:09:19  42.0970  42.0970     52.92
# ..          ...     ...                  ...      ...      ...       ...
# 572        Mana      GF  2021-12-02 19:27:28   5.6592   5.6592     81.28
# 573        Teya      RU  2021-12-02 19:27:28  60.3778  60.3778     26.33
# 574     Ha Tinh      VN  2021-12-02 19:27:29  18.3333  18.3333     59.13
# 575      Rawson      AR  2021-12-02 19:27:29 -43.3002 -43.3002     59.92
# 576      Tandil      AR  2021-12-02 19:27:30 -37.3217 -37.3217     85.30
#
#      Humidity  Cloudiness  Wind Speed
# 0          74           6       18.30
# 1          78          99       10.74
# 2          77          90        1.01
# 3          89          40        3.44
# 4          75          90       10.00
# ..        ...         ...         ...
# 572        75          77        8.43
# 573        84         100       12.06
# 574        72           4        4.63
# 575        50           6       16.64
# 576        29           0        4.00
#
# [577 rows x 9 columns]

# %%
save_data_tocsv = "weather_Database/weatherPy_Database.csv"
#export data to CSV
city_data_df.to_csv(save_data_tocsv,index_label="City_ID")
city_data_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-a51462693232> in <module>
#       1 save_data_tocsv = "weather_Database/weatherPy_Database.csv"
#       2 #export data to CSV
# ----> 3 city_data_df.to_csv(save_data_tocsv,index_label="City_ID")
#       4 city_data_df
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather_Database/weatherPy_Database.csv'

# %%
#Extract field for plotting
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
import time
today = time.strftime("%x")
today

# %%
import time
plt.scatter(lats,
            max_temps,
            edgecolor="black",linewidths=1,marker="o",alpha=0.8,label="Cities")
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.show()
plt.savefig("weather_data/Fig1.png")

# %%
plt.scatter(lats,
            humidity,
            edgecolors="black",linewidths=1,alpha=0.8,marker = "o",label = "Cities")
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
from scipy.stats import linregress

# %%
#create function to perform linear regression on the weather data
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
     # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
northern_hemi_df

# %%
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]
southern_hemi_df

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Humidity', 'Humidity',(10,40))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the southern Hemisphere \
                        for humidity', 'Humidity',(10,40))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the southern Hemisphere for Cloudiness', 'Cloudiness',(10,40))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Cloudiness', 'Cloudiness',(10,40))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(10,40))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(10,40))
